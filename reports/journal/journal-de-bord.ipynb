# %% [markdown]
# # Journal de bord - Certification CISIA
#
# Ce notebook sert de journal de bord pour tracer la démarche, les décisions et les arbitrages tout au long du projet.

# %% [markdown]
# ## Mode d'utilisation
#
# - Ajouter une entrée par session de travail.
# - Garder des traces factuelles : décisions, alternatives, raisons du choix.
# - Mentionner explicitement les impacts métier, éthique et technique.

# %% [markdown]
# ## Entrée type (copier-coller)
#
# ### Session
# - Date :
# - Durée :
# - Objectif de la session :
#
# ### Actions réalisées
# -
# -
# -
#
# ### Résultats observables
# - Métriques / constats :
# - Figures / tableaux produits :
# - Fichiers modifiés :
#
# ### Décisions prises
# - Décision 1 :
# - Justification :
# - Risque associé :
#
# ### Difficultés et résolutions
# - Problème :
# - Cause probable :
# - Résolution appliquée :
#
# ### Éthique / RGPD / biais
# - Point de vigilance identifié :
# - Impact potentiel :
# - Mesure de mitigation :
#
# ### Suite prévue
# - Prochaine étape 1 :
# - Prochaine étape 2 :

# %% [markdown]
# ---
# ## Première entrée - Session du 16/07/2026
#
# ### Session
# - Date : 16/07/2026
# - Durée : environ 1h30
# - Objectif de la session : structurer le dépôt pour la certification et préparer les livrables notebook + soutenance.
#
# ### Actions réalisées
# - Lecture du brief en Markdown et vérification du contenu du DOCX.
# - Vérification rapide du dataset (schéma, colonnes, présence de valeurs manquantes).
# - Création d'une arborescence de travail complète : data, src, models, reports, docs, tests, infra, logs.
# - Création de fichiers socle : README, plan notebook final, plan de présentation, workflow CI minimal, Makefile, .env.example.
# - Insertion d'une cellule de sommaire de rendu certification en tête du notebook final.
# - Création du template de journal de bord.
#
# ### Résultats observables
# - Constats : structure de projet claire et prête pour l'exécution du cas d'usage de bout en bout.
# - Figures / tableaux produits : aucun à ce stade (phase de cadrage et d'initialisation).
# - Fichiers modifiés : README.md, notebooks/PLAN_NOTEBOOK_FINAL.md, reports/soutenance/presentation-plan.md, .github/workflows/ci.yml, Makefile, .env.example, notebooks/multimodal-classification.ipynb, reports/journal/journal-de-bord-template.md
#
# ### Décisions prises
# - Décision 1 : travailler avec un dépôt structuré, même si le rendu officiel reste notebook + PowerPoint.
# - Justification : meilleure traçabilité, meilleure qualité de démarche, préparation plus simple de la soutenance.
# - Risque associé : dispersion possible entre trop d'artefacts techniques et le livrable final.
#
# ### Difficultés et résolutions
# - Problème : extraction directe du DOCX impossible via Expand-Archive sur extension .docx.
# - Cause probable : contrainte de l'outil qui accepte explicitement le format .zip.
# - Résolution appliquée : copie du .docx en .zip temporaire puis extraction et lecture XML.
#
# ### Éthique / RGPD / biais
# - Point de vigilance identifié : présence d'une variable sensible (nationalité hors UE) pouvant induire un biais.
# - Impact potentiel : discrimination algorithmique et non-conformité si usage non justifié.
# - Mesure de mitigation : prévoir une comparaison explicite avec scénario sans variable sensible et argumenter le choix final.
#
# ### Suite prévue
# - Prochaine étape 1 : démarrer l'EDA et le préprocessing documentés dans le notebook final.
# - Prochaine étape 2 : entraîner les modèles sur les 4 scénarios et comparer les métriques demandées.

# %% [markdown]
# ---
# ## Deuxième entrée - Session du 16/07/2026 (suite)
#
# ### Session
# - Date : 16/07/2026
# - Durée : environ 1h00
# - Objectif de la session : finaliser le cadrage métier (section 1), aligner la traçabilité et préparer la suite analytique.
#
# ### Actions réalisées
# - Rédaction complète de la section 1 dans le notebook final (contexte, problème IA, bénéficiaires, critères, risques).
# - Définition explicite de l'impact critique métier : erreurs classe 2 -> 0.
# - Structuration des critères de succès avec distinction cible initiale / cible révisée après EDA.
# - Mise à jour du decision log avec les décisions de cadrage métier et de gouvernance des variables sensibles.
# - Harmonisation de la terminologie entre notebook, journal et runbook.
#
# ### Résultats observables
# - Métriques / constats : cadre d'évaluation clarifié autour de F1 macro, recall classe 2 et erreurs critiques.
# - Figures / tableaux produits : tableau des critères de succès (section 1.4).
# - Fichiers modifiés : notebooks/multimodal-classification.ipynb, docs/runbooks/decision-log.md, reports/journal/journal-de-bord-template.md, reports/journal/journal-de-bord.ipynb.
#
# ### Décisions prises
# - Décision 1 : prioriser la réduction des erreurs critiques (2 -> 0) comme axe métier principal.
# - Justification : limiter la perte de chance d'accompagnement renforcé pour les profils les plus vulnérables.
# - Risque associé : compromis possible avec la précision sur les classes moins critiques.
#
# ### Difficultés et résolutions
# - Problème : risque de confusion entre objectifs métier et métriques techniques.
# - Cause probable : cadrage initial trop orienté score global.
# - Résolution appliquée : formalisation explicite de critères multi-axes (métier, modèle, opérationnel, gouvernance).
#
# ### Éthique / RGPD / biais
# - Point de vigilance identifié : usage potentiel d'une variable sensible (`nationalite_hors_ue`).
# - Impact potentiel : discrimination directe ou indirecte si l'arbitrage n'est pas documenté.
# - Mesure de mitigation : scénario imposé sans variable sensible + justification comparative en arbitrage final.
#
# ### Suite prévue
# - Prochaine étape 1 : compléter la section 2 (sources, volumétrie, dictionnaire, qualité initiale).
# - Prochaine étape 2 : lancer l'EDA section 3 pour valider/réviser les cibles de performance.

# %% [markdown]
# ---
# ## Troisième entrée - Session du 16/07/2026 (sections 2 et 3)
#
# ### Session
# - Date : 16/07/2026
# - Durée : environ 1h45
# - Objectif de la session : finaliser les sections 2 et 3 avec une EDA exploitable pour le préprocessing.
#
# ### Actions réalisées
# - Finalisation de la section 2 : source, volumétrie, dictionnaire des variables et synthèse acquisition.
# - Implémentation de la section 3 avec sous-sections 3.1 à 3.5 séparées en Markdown + code exécutable.
# - Ajout de visualisations clés : manquants, outliers IQR, distributions numériques, distribution cible, relations conditionnelles.
# - Refonte de l'affichage catégoriel en mode compact pour améliorer la lisibilité du notebook.
#
# ### Résultats observables
# - Métriques / constats :
#   - manquants principaux : `age` 4,88 %, `niveau_diplome` 3,36 %, `synthese_entretien` 3,24 %, `est_allocataire` 1,76 %,
#   - cible modérément déséquilibrée : classe 0 = 37,44 %, classe 1 = 44,48 %, classe 2 = 18,08 %.
# - Figures / tableaux produits : graphiques EDA + tableau distributions cible global/train/test.
# - Fichiers modifiés : notebooks/multimodal-classification.ipynb, docs/runbooks/decision-log.md, reports/journal/journal-de-bord.ipynb.
#
# ### Décisions prises
# - Décision 1 : privilégier une EDA orientée décision métier plutôt qu'un catalogue exhaustif de sorties.
# - Justification : meilleure lisibilité jury et lien direct avec la section 4.
# - Risque associé : certains signaux secondaires peuvent être reportés hors du flux principal.
#
# ### Difficultés et résolutions
# - Problème : les sorties des modalités catégorielles prenaient trop de place.
# - Cause probable : cardinalité élevée sur certaines variables et affichage exhaustif.
# - Résolution appliquée : ajout d'un mode compact pour afficher en priorité les modalités les plus fréquentes.
#
# ### Éthique / RGPD / biais
# - Point de vigilance identifié : écarts notables de distribution de la cible selon certaines variables potentiellement sensibles.
# - Impact potentiel : discrimination indirecte si non encadré en modélisation.
# - Mesure de mitigation : conservation d'un scénario sans variable sensible pour arbitrage comparatif ultérieur.
#
# ### Suite prévue
# - Prochaine étape 1 : démarrer la section 4 (split, préprocessing, scénarios).
# - Prochaine étape 2 : verrouiller un protocole anti-fuite avant la modélisation.

# %% [markdown]
# ---
# ## Quatrième entrée - Session du 16/07/2026 (section 4 clôturée)
#
# ### Session
# - Date : 16/07/2026
# - Durée : environ 1h30
# - Objectif de la session : finaliser la section 4 de bout en bout et confirmer sa clôture par des contrôles exécutables.
#
# ### Actions réalisées
# - Implémentation de la section 4.1 : split train/test stratifié, séparation X/y, exclusion de l'identifiant technique `usager_id`.
# - Construction de la section 4.2 : pipeline de préprocessing unifié (numérique, catégoriel, texte).
# - Structuration de la section 4.3 : formalisation des 4 scénarios imposés (S1 à S4) + cellule opérationnelle de contrôle.
# - Finalisation de la section 4.5 avec assertions qualité couvrant intégrité cible, split, features, préprocessing et scénarios.
# - Exécution de validation finale : assertions 4.5 toutes passées, section 4 formellement clôturée.
#
# ### Résultats observables
# - Métriques / constats :
#   - split validé : train (2000, 8), test (500, 8),
#   - préprocessing validé : train transformé (2000, 2136), test transformé (500, 2136),
#   - synthèse scénarios : S1=2136 features, S2=2135, S3=136, S4=2000,
#   - assertions 4.5 : toutes validées.
# - Figures / tableaux produits : tableau de distribution cible global/train/test + tableau comparatif des dimensions des scénarios.
# - Fichiers modifiés : notebooks/multimodal-classification.ipynb, docs/runbooks/decision-log.md, reports/journal/journal-de-bord.ipynb.
#
# ### Décisions prises
# - Décision 1 : imposer un protocole anti-fuite de données sur toutes les transformations apprenantes.
# - Justification : éviter toute contamination du test et garantir une évaluation fiable.
# - Risque associé : pipeline plus structuré donc maintenance plus rigoureuse des assertions.
#
# ### Difficultés et résolutions
# - Problème : confusion possible sur le rôle de `fit_transform` et `transform`.
# - Cause probable : proximité syntaxique des deux méthodes et transformations apprenantes multiples.
# - Résolution appliquée : règle opérationnelle explicite (fit uniquement sur train, transform ailleurs) + verrouillage par assertions.
#
# ### Éthique / RGPD / biais
# - Point de vigilance identifié : variable sensible `nationalite_hors_ue` à conserver uniquement dans les scénarios de comparaison encadrés.
# - Impact potentiel : biais discriminatoire si usage non contrôlé dans le scénario final.
# - Mesure de mitigation : maintien explicite du scénario sans variable sensible (S2) pour arbitrage en section 6.
#
# ### Suite prévue
# - Prochaine étape 1 : lancer la section 5 (modèles candidats + protocole CV sur train).
# - Prochaine étape 2 : préparer le tableau comparatif section 6 avec les 4 scénarios et les métriques métier.

# %% [markdown]
# ---
# ## Cinquième entrée - Session du 24/07/2026 (refonte portfolio du dépôt)
#
# ### Session
# - Date : 24/07/2026
# - Durée : environ 1h30
# - Objectif de la session : repositionner le dépôt comme projet de portfolio, avec un README et un notebook plus lisibles pour un recruteur ou un jury.
#
# ### Actions réalisées
# - Réécriture du README dans un ton plus naturel, moins scolaire et davantage orienté architecture, résultats, API, Docker et métriques.
# - Relecture éditoriale du notebook principal pour homogénéiser le ton, clarifier les transitions et améliorer la lisibilité des sections.
# - Nettoyage progressif des cellules mixtes pour remettre les titres de sous-sections en Markdown plutôt qu'en commentaire Python.
# - Création d'un commit conventionnel dédié à la refonte documentaire du repo et du notebook.
#
# ### Résultats observables
# - Métriques / constats : amélioration nette de la lisibilité narrative du dépôt et meilleure cohérence entre README, notebook et support de soutenance.
# - Figures / tableaux produits : aucun nouveau graphique ; travail centré sur la structure, le récit et la présentation.
# - Fichiers modifiés : README.md, notebooks/multimodal-classification.ipynb.
#
# ### Décisions prises
# - Décision 1 : assumer une présentation portfolio, sans perdre la rigueur méthodologique attendue pour la certification.
# - Justification : le dépôt doit à la fois servir de livrable académique et de vitrine de compétences data/ML/industrialisation.
# - Risque associé : basculer vers une forme trop marketing si les choix techniques ne restent pas explicités.
#
# ### Difficultés et résolutions
# - Problème : le ton initial du notebook et du README restait très scolaire et parfois redondant.
# - Cause probable : rédaction section par section sans harmonisation globale du récit.
# - Résolution appliquée : seconde passe éditoriale complète, recentrée sur la lisibilité, l'architecture et les arbitrages.
#
# ### Éthique / RGPD / biais
# - Point de vigilance identifié : ne pas gommer les limites du modèle au profit d'une présentation plus "vitrine".
# - Impact potentiel : perception trompeuse du niveau réel de robustesse si les risques métier et biais résiduels sont sous-documentés.
# - Mesure de mitigation : conserver les limites, les scénarios comparatifs et les risques résiduels comme éléments explicites du récit.
#
# ### Suite prévue
# - Prochaine étape 1 : finaliser la section 5 avec des résultats exécutés et défendables.
# - Prochaine étape 2 : préparer la section 6 pour transformer les scores en arbitrage métier explicite.

# %% [markdown]
# ---
# ## Sixième entrée - Session du 24/07/2026 (sections 5 et 6 finalisées)
#
# ### Session
# - Date : 24/07/2026
# - Durée : environ 2h00
# - Objectif de la session : exécuter la comparaison des modèles, finaliser le tuning ciblé et transformer les résultats en arbitrage métier explicite.
#
# ### Actions réalisées
# - Implémentation et exécution de la section 5.2 avec validation croisée stratifiée sur les 4 scénarios et plusieurs modèles candidats.
# - Construction du tableau de comparaison de la section 5.4 pour classer les couples scénario-modèle.
# - Simplification de la stratégie de tuning : recherche d'hyperparamètres restreinte au couple classé rang 1.
# - Exécution de l'évaluation finale sur le test set avec matrice de confusion et synthèse des métriques.
# - Rédaction de la section 6 avec tableau comparatif complet S1 à S4, recommandation finale et risques résiduels.
#
# ### Résultats observables
# - Métriques / constats :
#   - meilleur couple initial en CV : `S1_multimodal_complet + xgboost`,
#   - après tuning local : CV F1 macro = 0,714 ; CV recall classe 2 = 0,591,
#   - sur test final : accuracy = 0,754 ; F1 macro = 0,724 ; recall classe 2 = 0,500,
#   - erreurs critiques observées : 8 cas `2 -> 0` sur 90 cas de classe 2 dans le test set.
# - Figures / tableaux produits : tableau comparatif section 5.4, tableau de tuning section 5.5, matrice de confusion finale, tableau d'arbitrage section 6.1.
# - Fichiers modifiés : notebooks/multimodal-classification.ipynb, docs/runbooks/decision-log.md, reports/journal/journal-de-bord.ipynb.
#
# ### Décisions prises
# - Décision 1 : retenir le couple `S1 + XGBoost` comme baseline finale malgré un rappel de classe 2 insuffisant.
# - Justification : meilleure performance globale observée en test et cohérence avec la logique de comparaison multimodale.
# - Risque associé : maintien d'un risque métier significatif sur les faux négatifs critiques.
#
# ### Difficultés et résolutions
# - Problème : tension entre simplicité du notebook, qualité globale des scores et priorité métier sur la classe 2.
# - Cause probable : compromis structurel entre performance moyenne et détection robuste de la classe minoritaire la plus sensible.
# - Résolution appliquée : limiter le tuning au couple rang 1, puis expliciter en section 6 que la décision finale reste conditionnée à des garde-fous humains.
#
# ### Éthique / RGPD / biais
# - Point de vigilance identifié : le scénario S1 reste le plus performant mais inclut la variable sensible `nationalite_hors_ue`.
# - Impact potentiel : risque accru de discrimination directe ou indirecte si le modèle est déployé sans encadrement.
# - Mesure de mitigation : comparaison documentée avec S2, usage assistif plutôt qu'autonome, monitoring spécifique des erreurs critiques et des sous-groupes.
#
# ### Suite prévue
# - Prochaine étape 1 : compléter la section 7 avec une stratégie d'abstention ou d'escalade humaine basée sur la confiance prédictive.
# - Prochaine étape 2 : enrichir les sections 8 et 9 pour relier plus explicitement modèle final, API, monitoring et amélioration continue.

# %% [markdown]
# ---
# ## Septième entrée - Session du 27/07/2026 (section 7 affinée + limite data texte consolidée)
#
# ### Session
# - Date : 27/07/2026
# - Durée : environ 1h30
# - Objectif de la session : finaliser la stratégie d'escalade humaine de la section 7 et consolider la limite de qualité texte dans la synthèse EDA.
#
# ### Actions réalisées
# - Relecture et clarification des sous-sections 7.2 et 7.2.1 pour distinguer la règle simple (seuil de confiance) de la règle combinée (confiance + risque classe 2).
# - Ajout d'exemples pédagogiques courts pour rendre la logique de seuil et d'escalade plus compréhensible.
# - Ajustement de la synthèse 7.4 pour refléter le compromis opérationnel : capture du risque critique vs charge de reprise manuelle.
# - Intégration explicite, en section 3.7, de la faible diversité textuelle comme limite méthodologique du signal NLP.
# - Mise à jour de la traçabilité des décisions dans le decision log.
#
# ### Résultats observables
# - Métriques / constats :
#   - les courbes de politique simple et combinée peuvent se superposer sur plusieurs seuils, indiquant un gain marginal selon la calibration,
#   - l'arbitrage reste principalement piloté par la capacité de revue humaine et la réduction des erreurs critiques 2 -> 0,
#   - la faible diversité des verbatims limite la robustesse des conclusions sur l'apport du texte.
# - Figures / tableaux produits : actualisation des visualisations de calibration section 7.2.1 et de la synthèse interprétative associée.
# - Fichiers modifiés : notebooks/multimodal-classification.ipynb, docs/runbooks/decision-log.md, reports/journal/journal-de-bord.ipynb.
#
# ### Décisions prises
# - Décision 1 : maintenir une posture de modèle assistif avec escalade des cas incertains plutôt qu'un usage autonome.
# - Justification : meilleure maîtrise du risque métier sur les erreurs critiques malgré un coût opérationnel de reprise manuelle.
# - Risque associé : surcharge de traitement si le seuil d'escalade est fixé trop haut.
#
# ### Difficultés et résolutions
# - Problème : incompréhension potentielle de l'effet du seuil de confiance (plus le seuil monte, plus l'escalade augmente).
# - Cause probable : inversion intuitive entre "confiance requise" et "nombre de cas considérés sûrs".
# - Résolution appliquée : ajout d'exemples concrets de probabilités de sortie modèle et repositionnement pédagogique des explications entre 7.2 et 7.2.1.
#
# ### Éthique / RGPD / biais
# - Point de vigilance identifié : la qualité limitée des verbatims peut masquer des biais ou des corrélations fragiles dans le signal texte.
# - Impact potentiel : sur-confiance dans des gains NLP peu généralisables et risque de décisions inéquitables si le signal est instable.
# - Mesure de mitigation : formaliser cette limite dans la synthèse, maintenir un contrôle humain sur les cas sensibles et prioriser l'amélioration de la collecte texte.
#
# ### Suite prévue
# - Prochaine étape 1 : stabiliser un seuil d'escalade cible avec contrainte explicite de capacité opérationnelle.
# - Prochaine étape 2 : relier la stratégie d'escalade aux indicateurs de monitoring section 9 (taux d'escalade, erreurs critiques résiduelles, dérive des données texte).

# %% [markdown]
# ---
# ## Trace minimale attendue pour le jury
#
# - Cadrage métier
# - Qualité des données et preprocessing
# - Comparaison des 4 scénarios
# - Réduction des erreurs critiques (2 -> 0)
# - Arbitrages finaux et limites
# - Proposition d'industrialisation
